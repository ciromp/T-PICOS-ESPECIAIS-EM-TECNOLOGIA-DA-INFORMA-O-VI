# %%
import numpy as np
import matplotlib.pyplot as plt

partidas = []

for k in range(0,500):

        andares = []
        andar_atual = 0 #np.random.randint(0,100)
        andares.append(andar_atual)

        for y in range(0,100):
                dado = np.random.randint(1,7)
                if dado == 1:
                        if andar_atual > 0:
                                andar_atual -= 1
                elif dado == 2:
                        if andar_atual > 0:
                                andar_atual -= 1

                elif dado == 3:
                        andar_atual += 1

                elif dado == 4:
                        andar_atual += 1

                elif dado == 5:
                        andar_atual += 1

                elif dado == 6:
                        andar_atual += np.random.randint(1,7)

                prob = np.random.rand(1)
                if prob <= 0.001:
                            andar_atual = 0
                
                andares.append(andar_atual)

        partidas.append(andares)

total = np.array(partidas)

plt.plot(total)
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-124eec42c921> in <module>()
#      21    "cell_type": "markdown",
#      22    "metadata": {
# ---> 23     "collapsed": false
#      24    },
#      25    "source": [
#
# NameError: name 'false' is not defined
